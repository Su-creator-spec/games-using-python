# %%
print("welcome to my computer quiz")
playing=input("dp you want to play ? ")
player = input("what your name ? ")

if playing.lower()!="yes":
  quit()

print("Okay !lets play ")
print("rollyour sleeves up "+ player)
score= 0

answer=input("what does CPU stand for?     ")
if answer == "central processing unit ":
  print("correct!")
  score += 1
else:
  print("incorrect!")


answer=input("what does GPU stand for ?    ")
if answer == "graphics processing unit ":
  print("correct!")
  score += 1
else:
  print("incorrect!")

answer=input("what does Ram stand for ?     ")
if answer == "random processing unit ":
  print("correct!")
  score += 1
else:
  print("incorrect!")

answer=input("what does PSU stand for?     ")
if answer == "power supply unit ":
  print("correct!")
  score += 1
else:
  print("incorrect!")

print("you got"+str(score)+"questions correct ")
print("you have got"+str((score/4)*100)+"%")
# Out:
# welcome to my computer quiz
# dp you want to play ? yes
# what your name ? summi
# Okay !lets play
# rollyour sleeves up summi
# what does CPU stand for?     cpu
# incorrect!
# what does GPU stand for ?    jklk
# incorrect!
# what does Ram stand for ?     nkl
# incorrect!
# what does PSU stand for?     lml;
# incorrect!
# you got0questions correct
# you have got0.0%
