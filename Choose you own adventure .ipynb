# %%
name = input("type you name : ")
print("welcome",name,"to this adventure ")

answer = input(" you have come to an dirt road which way would you like to go right or left ? ").lower()

if answer == "left ":
  answer= input("you have come to a river would you choose to walk around or swim across? type walk to walkk around and swim to swim across the river ")
  if answer == "walk":
    print("you walked for many miles , you ran out of water and you lost ")

  elif answer == "swim":
    print("you swam across and you were eaten by an alligator ")

  else:
    print("choose a valid path . you loose ")

elif answer =="right":
  answer =input("you reach to a bridge , it looks wobbly , would you cross it or return back (cross/back)? ")
  if answer == "cross":
    answer=input("you crossed the bridge ,you met a stranger would you talk to them (yes/no ) ? ")
    if answer == "yes":
      print("you talked to the stranger , and you got gold and you win !!!!")
    elif answer == "no":
      print("you ignored the stranger and you got stabbed and you loose ")
    else:
      print("choose a valid path . you loose ")

  elif answer == "back":
    print("you go back and loose")

  else:
    print("choose a valid path . you loose ")



else:
  print("choose a valid path . you loose ")
# Out:
# type you name : sumehara
# welcome sumehara to this adventure
#  you have come to an dirt road which way would you like to go right or left ? right
# you reach to a bridge , it looks wobbly , would you cross it or return back (cross/back)? cross
# you crossed the bridge ,you met a stranger would you talk to them (yes/no ) ? yes
# you talked to the stranger , and you got gold and you win !!!!
